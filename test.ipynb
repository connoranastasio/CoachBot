# %%
from peppi_py import read_slippi, read_peppi
import pathlib
dpath = pathlib.Path('/mnt/d')

# %%
for item in dpath.iterdir():
    print(item)
# Out:
# /mnt/d/$RECYCLE.BIN
# /mnt/d/agents
# /mnt/d/Install Western Digital Software for Mac.dmg
# /mnt/d/Install Western Digital Software for Windows.exe
# /mnt/d/phillip
# /mnt/d/slippi replays
# /mnt/d/slippi replays.rar
# /mnt/d/slippi-ai
# /mnt/d/slippi-stats
# /mnt/d/System Volume Information
# /mnt/d/win-mw-push

# %%
mayfiles = pathlib.Path('/mnt/d/slippi replays/bambi 2023-2025/2025/2025-05')

# %%
for item in mayfiles.iterdir():
    print(item)
# Out:
# /mnt/d/slippi replays/bambi 2023-2025/2025/2025-05/Game_20250501T135637.slp
# /mnt/d/slippi replays/bambi 2023-2025/2025/2025-05/Game_20250501T135913.slp
# /mnt/d/slippi replays/bambi 2023-2025/2025/2025-05/Game_20250501T140132.slp
# /mnt/d/slippi replays/bambi 2023-2025/2025/2025-05/Game_20250501T140322.slp
# /mnt/d/slippi replays/bambi 2023-2025/2025/2025-05/Game_20250501T140537.slp
# /mnt/d/slippi replays/bambi 2023-2025/2025/2025-05/Game_20250501T140822.slp
# /mnt/d/slippi replays/bambi 2023-2025/2025/2025-05/Game_20250501T140947.slp
# /mnt/d/slippi replays/bambi 2023-2025/2025/2025-05/Game_20250501T141229.slp
# /mnt/d/slippi replays/bambi 2023-2025/2025/2025-05/Game_20250501T141609.slp
# /mnt/d/slippi replays/bambi 2023-2025/2025/2025-05/Game_20250501T141927.slp
# /mnt/d/slippi replays/bambi 2023-2025/2025/2025-05/Game_20250501T142118.slp
# /mnt/d/slippi replays/bambi 2023-2025/2025/2025-05/Game_20250501T142443.slp
# ...

# %%
samplefile = mayfiles /'Game_20250501T135637.slp'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 samplefile = mayfiles /'Game_20250501T135637.slp'
#       2 with samplefile.open() as f:
# ----> 3     game = read_slippi(f)
#
# File ~/Documents/projects/CoachBot/.venv/lib/python3.10/site-packages/peppi_py/__init__.py:12, in read_slippi(path, skip_frames)
#      11 def read_slippi(path: str, skip_frames: bool=False) -> Game:
# ---> 12 	g = _read_slippi(path, skip_frames)
#      13 	return Game(dc_from_json(Start, g.start), dc_from_json(End, g.end), g.metadata, frames_from_sa(g.frames))
#
# TypeError: argument 'path': 'TextIOWrapper' object cannot be converted to 'PyString'

# %%
game = read_slippi(str(samplefile))

# %%
game.metadata
# Out:
# {'startAt': '2025-05-01T17:56:37Z',
#  'lastFrame': 8927,
#  'players': {'0': {'names': {'netplay': 'drpepprisawoman', 'code': 'HBOX#69'},
#    'characters': {'1': 9169}},
#   '1': {'names': {'netplay': 'u cant combo', 'code': 'NIKE#173'},
#    'characters': {'22': 9169}}},
#  'playedOn': 'dolphin'}

# %%
dir(game)
# Out:
# ['__annotations__',
#  '__class__',
#  '__dataclass_fields__',
#  '__dataclass_params__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__match_args__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'end',
#  'frames',
#  'metadata',
#  'start']

# %%
[x for x in dir(game) if not x.startswith('_')]
# Out:
# ['end', 'frames', 'metadata', 'start']

# %%
game.frames()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 game.frames()
#
# TypeError: 'Frame' object is not callable

# %%
game.frames
# Out:
# Frame(id=[-123, -122, -121, ...], ports=(PortData(leader=Data(pre=Pre(random_seed=[58198, 123734, 189270, ...], state=[322, 322, 322, ...], position=Position(x=[-41.25, -41.25, -41.25, ...], y=[21.0, 21.0, 21.0, ...]), direction=[1.0, 1.0, 1.0, ...], joystick=Position(x=[0.0, 0.0, 0.0, ...], y=[0.0, 0.0, 0.0, ...]), cstick=Position(x=[0.0, 0.0, 0.0, ...], y=[0.0, 0.0, 0.0, ...]), triggers=[0.0, 0.0, 0.0, ...], buttons=[0, 0, 0, ...], buttons_physical=[0, 0, 0, ...], triggers_physical=TriggersPhysical(l=[0.0, 0.0, 0.0, ...], r=[0.0, 0.0, 0.0, ...]), raw_analog_x=[0, 0, 0, ...], percent=[0.0, 0.0, 0.0, ...], raw_analog_y=[0, 0, 0, ...]), post=Post(character=[1, 1, 1, ...], state=[322, 322, 322, ...], position=Position(x=[-41.25, -41.25, -41.25, ...], y=[21.0, 21.0, 21.0, ...]), direction=[1.0, 1.0, 1.0, ...], percent=[0.0, 0.0, 0.0, ...], shield=[60.0, 60.0, 60.0, ...], last_attack_landed=[0, 0, 0, ...], combo_count=[0, 0, 0, ...], last_hit_by=[6, 6, 6, ...], stocks=[4, 4, 4, ...], sta
# ...

# %%
type(game.frames)
# Out:
# peppi_py.frame.Frame

# %%
for frame in game.frames:
    print(frame)
    break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 for frame in game.frames:
#       2     print(frame)
#       3     break
#
# TypeError: 'Frame' object is not iterable

# %%
posdata =
